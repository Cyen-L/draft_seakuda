# %%
import tiflash
# 直接指定包含 eclipse 和 ccs_base 的文件夹
tiflash.detect_devices(ccs="C:/ti/ccs2101/ccs")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\Visual Studio Code\draft\env\Lib\site-packages\tiflash\core\api.py:67, in __handle_ccs(ccs)
#      66 try:    #TODO: Hacky? Look into better solution
# ---> 67     int(ccs.replace('.',''))    # Throws error if not a version number
#      68     ccs_path = find_ccs(version=ccs)
#
# ValueError: invalid literal for int() with base 10: 'C:/ti/ccs2101/ccs'
#
# During handling of the above exception, another exception occurred:
#
# FindCCSError                              Traceback (most recent call last)
# Cell In[14], line 3
#       1 import tiflash
#       2 # 直接指定包含 eclipse 和 ccs_base 的文件夹
# ----> 3 tiflash.detect_devices(ccs="C:/ti/ccs2101/ccs")
#
# File ~\Documents\Visual Studio Code\draft\env\Lib\site-packages\tiflash\core\api.py:876, in detect_devices(ccs, **session_args)
# ...

# %%
import os
os.environ['CCS_PREFIX'] = 'C:/ti'
import tiflash
tiflash.detect_devices()
# Out:
# ---------------------------------------------------------------------------
# FindCCSError                              Traceback (most recent call last)
# Cell In[13], line 4
#       1 import os
#       2 os.environ['CCS_PREFIX'] = 'C:/ti'
#       3 import tiflash
# ----> 4 tiflash.detect_devices()
#
# File ~\Documents\Visual Studio Code\draft\env\Lib\site-packages\tiflash\core\api.py:876, in detect_devices(ccs, **session_args)
#     870 def detect_devices(ccs=None, **session_args):
#     871     """Detect devices connected to machine.
#     872
#     873     Returns:
#     874         list: list of dictionaries describing connected devices
#     875     """
# --> 876     ccs_path = __handle_ccs(ccs)
#     878     device_list = list()
#     879     detected_devices = detect.detect_devices()
#
# File ~\Documents\Visual Studio Code\draft\env\Lib\site-packages\tiflash\core\api.py:57, in __handle_ccs(ccs)
#      54 ccs_path = None
#      56 if ccs is None: # Get latest ccs installation
# ...

# %%
tiflash.get_info(ccs="7")
# Out:
# {'tiflash version': '1.3.0',
#  'release date': '2022.07.05',
#  'python version': '3.12.10',
#  'ccs version': 'N/A',
#  'ccs location': 'N/A',
#  'ccs prefix': 'C:\\ti',
#  'device drivers': 'N/A'}

# %%
tiflash.get_info(ccs="8.1")
# Out:
# {'tiflash version': '1.3.0',
#  'release date': '2022.07.05',
#  'python version': '3.12.10',
#  'ccs version': 'N/A',
#  'ccs location': 'N/A',
#  'ccs prefix': 'C:\\ti',
#  'device drivers': 'N/A'}

# %%
tiflash.detect_devices()
# Out:
# ---------------------------------------------------------------------------
# FindCCSError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tiflash.detect_devices()
#
# File ~\Documents\Visual Studio Code\draft\env\Lib\site-packages\tiflash\core\api.py:876, in detect_devices(ccs, **session_args)
#     870 def detect_devices(ccs=None, **session_args):
#     871     """Detect devices connected to machine.
#     872
#     873     Returns:
#     874         list: list of dictionaries describing connected devices
#     875     """
# --> 876     ccs_path = __handle_ccs(ccs)
#     878     device_list = list()
#     879     detected_devices = detect.detect_devices()
#
# File ~\Documents\Visual Studio Code\draft\env\Lib\site-packages\tiflash\core\api.py:57, in __handle_ccs(ccs)
#      54 ccs_path = None
#      56 if ccs is None: # Get latest ccs installation
# ---> 57     ccs_path = find_ccs()
#      59 else:
#      60
# ...
